# %% [markdown]
# # Test API

# %%
import requests
import json

# %% [markdown]
# ## Local API Test

# %%
url = 'http://localhost:8000/'

# %%
response = requests.get(url)

# %%
json.loads(response.text)
# Out:
# {'name': 'Student Dropout Predictor API',
#  'version': '1.0',
#  'docs_url': '/docs',
#  'endpoints': {'predict': '/predict',
#   'documentation': '/docs',
#   'openapi': '/openapi.json'}}

# %%
url = "http://localhost:8000/predict"

# %%
params = {
  "Age_at_enrollment": 40,
  "Curricular_units_1st_sem_approved": 2,
  "Curricular_units_2nd_sem_approved": 5,
  "Curricular_units_1st_sem_without_evaluations": 1,
  "Curricular_units_2nd_sem_without_evaluations": 2,
  "Curricular_units_1st_sem_grade": 14.0,
  "Curricular_units_2nd_sem_grade": 14.0,
  "Tuition_fees_up_to_date": 0,
  "Scholarship_holder": 0
}
response = requests.post(url, json=params)
json.loads(response.text)
print(response.text)
# Out:
# {"dropout_probability":0.885,"risk_category":"High Risk"}

# %% [markdown]
# ## Local Docker API Test

# %%
url = "http://0.0.0.0:80"

# %%
response = requests.get(url)
json.loads(response.text)
# print(response.text)
# Out:
# {'name': 'Student Dropout Predictor API',
#  'version': '1.0',
#  'docs_url': '/docs',
#  'endpoints': {'predict': '/predict',
#   'documentation': '/docs',
#   'openapi': '/openapi.json'}}

# %%
url = "http://0.0.0.0:80/predict"

# %%
params = {
  "Age_at_enrollment": 40,
  "Curricular_units_1st_sem_approved": 2,
  "Curricular_units_2nd_sem_approved": 5,
  "Curricular_units_1st_sem_without_evaluations": 1,
  "Curricular_units_2nd_sem_without_evaluations": 2,
  "Curricular_units_1st_sem_grade": 14.0,
  "Curricular_units_2nd_sem_grade": 14.0,
  "Tuition_fees_up_to_date": 0,
  "Scholarship_holder": 0
}
response = requests.post(url, json=params)
json.loads(response.text)
print(response.text)
# Out:
# {"dropout_probability":0.885,"risk_category":"High Risk"}

# %% [markdown]
# ## Test AWS API

# %%
url = "http://18.216.149.175:80"

# %%
response = requests.get(url)
json.loads(response.text)
# print(response.text)
# Out:
# {'name': 'Student Dropout Predictor API',
#  'version': '1.0',
#  'docs_url': '/docs',
#  'endpoints': {'predict': '/predict',
#   'documentation': '/docs',
#   'openapi': '/openapi.json'}}

# %%
url = "http://18.216.149.175:80/predict"

# %%
params = {
  "Age_at_enrollment": 40,
  "Curricular_units_1st_sem_approved": 2,
  "Curricular_units_2nd_sem_approved": 5,
  "Curricular_units_1st_sem_without_evaluations": 1,
  "Curricular_units_2nd_sem_without_evaluations": 2,
  "Curricular_units_1st_sem_grade": 14.0,
  "Curricular_units_2nd_sem_grade": 14.0,
  "Tuition_fees_up_to_date": 0,
  "Scholarship_holder": 0
}
response = requests.post(url, json=params)
json.loads(response.text)
print(response.text)
# Out:
# {"dropout_probability":0.885,"risk_category":"High Risk"}
